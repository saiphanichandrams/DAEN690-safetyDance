# %%
# First time loading this notebook? Should run this first!
# !pip install -r ./Scripts/requirements.txt
# %run -i "./Scripts/presetup.py"

# %%
#Searching for a single category
# %run -i "./Scripts/package_handling.py"
# %run -i "./Scripts/review_downloader.py"
# %run -i "./Scripts/filtering_preprocessing.py"
# %run -i "./Scripts/data_merge.py"
# %run -i "./Scripts/sentiment_analysis.py"
# %run -i "./Scripts/word_matching.py"
# %run -i "./Scripts/recall_merge.py"
# %run -i "./Scripts/aggregation_and_heuristic.py"
# %run -i "./Scripts/isoforest.py"

# %%
# Want to wait about 2 weeks and take up ~100gb? Run this one. Compiles ALL CATEGORIES.
# %run -i "./Scripts/Big_Loop.py"
# Out:
# Package handling complete!
# ...
# CUDA detected. Using GPU for processing.
# Loading refined synonyms: 100%|██████████| 192/192 [00:02<00:00, 73.68it/s]
# Pre-processing incident dataset
# Preprocessing Recall Dataset.
#
# Processing category: Beauty and Personal Care
#
# ...
